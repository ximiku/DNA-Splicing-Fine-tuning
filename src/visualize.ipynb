# %% [markdown]
# # Splice-Site Visualization TODOs
#
# This notebook is intentionally a lightweight interface stub for future analysis.
#
# Planned views:
# - sequence logos around donor/acceptor centers
# - ROC and PR curves
# - confusion matrix heatmaps
# - training/evaluation curves
# - DNABERT2 embedding projections
# - attribution heatmaps over 401 bp windows

# %%
from pathlib import Path
import pandas as pd


def load_predictions(path: str | Path) -> pd.DataFrame:
    """Load a parquet prediction table produced by train_dnabert2.py or baselines.py."""
    return pd.read_parquet(path)


def plot_confusion_matrix(predictions: pd.DataFrame):
    """TODO: render a confusion matrix from label and pred_label columns."""
    raise NotImplementedError


def plot_roc_pr_curves(predictions: pd.DataFrame):
    """TODO: render one-vs-rest ROC and PR curves for all three classes."""
    raise NotImplementedError


def plot_sequence_logo(dataset_split):
    """TODO: render centered sequence logos for donor, acceptor, and negatives."""
    raise NotImplementedError
